# %% [markdown]
# # Описание проекта:
#
# **Мотивация:** Среди моих знакомых и родных в последнее время часто идут разговоры о недвижимости в москве,  у кого-то она есть, а кто-то планирует переезжать да и я сам хочу пресмотреть что-нибудь в МО. Поэтому решил разобраться в этой теме и используя отрытые данные построить модель оценки стоимости домов и таунхаусов (позже возможно добавлю квартиры).
#
# **Цель:** Создать модель машинного обучения для предсказания стоимости недвижимости (дома и таунхаусы) в Москве и подмосковье с использованием данных, полученных с помощью библиотеки Cianparser.
#
# **Целевая аудитория:**
#
# * Жители Москвы и московской области, владеющие недвижимостью и желающие оценить её стоимость.
# * Люди, планирующие переезд в Раменское или Жуковский и интересующиеся ценами на недвижимость.
#
# **Инструменты:**
#
# * Python
# * Библиотека Cianparser для сбора данных
# * Библиотеки машинного обучения (Scikit-learn)
# * Streamlit для создания интерактивного приложения
#
# **Ожидаемые результаты:**
#
# * Модель машинного обучения с MAPE <= 0.2, способная точно предсказывать стоимость недвижимости.
# * Интерактивное приложение Streamlit, позволяющее пользователям вводить характеристики недвижимости и получать прогноз цены.

# %% [markdown]
# ## Парсинг данных

# %%
import time
from tqdm import tqdm
import chime
import pandas as pd
import numpy as np

from geopy.geocoders import Nominatim

from bs4 import BeautifulSoup
import cianparser
import requests
import re

chime.theme('mario')
# %load_ext chime
# Out:
# The chime extension is already loaded. To reload it, use:
#   %reload_ext chime

# %%
locs = pd.DataFrame(cianparser.list_locations()) 
locs.columns = ['Город','Индекс']

# %%
locs[locs['Город'] == 'Красногорск']
# Out:
#            Город  Индекс
# 126  Красногорск  175071

# %%
locations = ['Жуковский','Раменское','Одинцово','Домодедово',
            'Реутов','Железнодорожный','Долгопрудный','Москва',
            'Красногорск','Подольск','Балашиха']

# %%
def parce_suburban(city, suburban_types = ["house",'townhouse'], pages_ranges = [[1,1],[1,1]],
                   parsed_pages=0,return_counter=False, old_df=pd.read_csv('suburban.csv')):
    
    """
    Парсит данные о загородной недвижимости с сайта Циан для заданного города и типов недвижимости.

    Args:
        city (str): Название города для парсинга.
        suburban_types (list): Список типов загородной недвижимости (например, "house", "townhouse").
        pages_ranges (list): Список диапазонов страниц для парсинга для каждого типа недвижимости.
        parsed_pages (int): Количество уже спарсенных страниц (для управления таймаутами).
        return_counter (bool): Если True, возвращает также количество спарсенных страниц.
        old_df (pd.DataFrame): DataFrame с ранее спарсенными данными для проверки на дубликаты.

    Returns:
        pd.DataFrame or tuple: DataFrame с новыми данными о загородной недвижимости или кортеж 
                               (DataFrame, количество спарсенных страниц), если return_counter=True.
    """
    
    parser = cianparser.CianParser(location=city)
    df = pd.DataFrame()
    data = []

    for suburban_type,pages_range in zip(suburban_types,pages_ranges):
        for page in range(pages_range[0], pages_range[1]+1):
            
            print(f'-----------------------------')
            print(f'Локация: {city}')
            print(f'Вид недвижимости: {suburban_type}')
            print()
            
            # Проверка есть-ли новые ссылки
            fast_suburban_sale = pd.DataFrame(parser.get_suburban( 
                                                deal_type="sale",
                                                suburban_type = suburban_type,
                                                additional_settings={"start_page":page,
                                                                    "end_page":page}
                                                ))
            if fast_suburban_sale.shape[0] > 0:
            
                ids = [x not in old_df['url'].to_list() for x in fast_suburban_sale['url'].to_list()]
                new_df = fast_suburban_sale[ids]
                new_size = new_df.shape[0]

                # Если есть, то скачивается страница с новыми данными
                if new_size > 0:
                    print(f'-----------------------------')
                    print(f'Найдено новых обьявлений: {new_size}')
                    print(f'-----------------------------')
                    if parsed_pages >= 2:
                        num = np.random.randint(100,120)
                        print(f'parsed pages: {parsed_pages}')
                        print(f'timeout: {num}')
                        time.sleep(num)
                        
                    suburban_sale = pd.DataFrame(parser.get_suburban( 
                                                        deal_type="sale",
                                                        suburban_type = suburban_type,
                                                        with_extra_data=True,
                                                        additional_settings={"start_page":page,
                                                                            "end_page":page}
                                                        ))
                    ids = [x not in old_df['url'].to_list() for x in suburban_sale['url'].to_list()]
                    good_sales = suburban_sale[ids]
                    
                    data.append(good_sales)
                    parsed_pages +=1
                else:
                    print(f'-----------------------------')
                    print(f'Новых обьявлений не найдено')
                    print(f'-----------------------------')
                    pass
            else:
                print(f'-----------------------------')
                print(f'Новых обьявлений не найдено')
                print(f'-----------------------------')
                pass

    # Список словарей из полученных данных преобразется в датафрейм

    if len(data) > 0:
        df = pd.concat(data).drop_duplicates().reset_index(drop=True)
    
    if return_counter:
        return df,parsed_pages
    else:
        return df

# %%
def create_address(row, reverse_order=False, drop_district=False, with_mo = True):
    """
    Формирует полный адрес объекта недвижимости из отдельных столбцов DataFrame.

    Args:
        row (pd.Series): Строка DataFrame, содержащая информацию об адресе.
        reverse_order (bool): Если True, формирует адрес в обратном порядке.

    Returns:
        str: Полный адрес объекта недвижимости.
    """
    country = 'Россия, '

    if with_mo:
        MO = 'Московская область, '
    else:
        MO = ''

    if reverse_order:
        if drop_district:
            address = country + MO + f"{row['location']}, {row['street']}, {row['house_number']}" 
        else:
            address = country + MO + f"{row['location']}, {row['district']}, {row['street']}, {row['house_number']}" 
    else:
        if drop_district:
            address = country + MO + f"{row['street']}, {row['house_number']}, {row['location']}" 
        else:
            address = country + MO + f"{row['street']}, {row['house_number']}, {row['district']}, {row['location']}"

    address = address.strip().replace(", , ,", ",").replace(", ,", ",")
    if address.startswith(","):
        address = address[1:]
    return address

geolocator = Nominatim(user_agent="my_app", timeout=60)

# %%
def geocode_address(row):
    """
    Геокодирует адрес с помощью OpenStreetMap API, пробуя различные варианты адреса.

    Args:
        row (pd.Series): Строка DataFrame, содержащая информацию об адресе.

    Returns:
        tuple: Координаты (latitude, longitude) объекта, если геокодирование успешно, иначе None.
    """
    address_options = [
        create_address(row.fillna('')),
        create_address(row.fillna(''), reverse_order=True),
        create_address(row.fillna(''), drop_district=True),
        create_address(row.fillna(''), reverse_order=True, drop_district=True),
        create_address(row.fillna(''), with_mo=False),
        create_address(row.fillna(''), reverse_order=True, with_mo=False),
        create_address(row.fillna(''), drop_district=True, with_mo=False),
        create_address(row.fillna(''), reverse_order=True, drop_district=True, with_mo=False),
    ]

    for address in address_options:
        try:
            location = geolocator.geocode(address)
            return (location.latitude, location.longitude)
        except:
            try:
                location = geolocator.geocode(address).replace('-я','')
                return (location.latitude, location.longitude)
            except:
                pass  # Продолжаем пробовать другие варианты адреса

    return None  # Если ни один вариант не сработал

# %%
# %%time
# %%chime
dfs = []
old_df = pd.read_csv('suburban.csv')
counter = 0

for location in locations:
    
    df,counter = parce_suburban(location, parsed_pages = counter, return_counter = True,
                                old_df=old_df)
    if not df.empty:
        dfs.append(df)
# Out:
# -----------------------------
# Локация: Жуковский
# Вид недвижимости: house
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4750&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 36 375 347 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Найдено новых обьявлений: 1
# -----------------------------
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4750&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 36 375 347 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Локация: Жуковский
# Вид недвижимости: townhouse
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4750&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>] 100% | Count of all parsed: 2. Progress ratio: 100 %. Average price: 18 700 000 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 2.
# -----------------------------
# Новых обьявлений не найдено
# -----------------------------
# -----------------------------
# Локация: Раменское
# Вид недвижимости: house
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175758&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 49 507 025 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Новых обьявлений не найдено
# -----------------------------
# -----------------------------
# Локация: Раменское
# Вид недвижимости: townhouse
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175758&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 25. Progress ratio: 100 %. Average price: 59 002 848 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 25.
# -----------------------------
# Найдено новых обьявлений: 11
# -----------------------------
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175758&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>  ] 96% | Count of all parsed: 24. Progress ratio: 96 %. Average price: 58 362 848 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 25. Progress ratio: 100 %. Average price: 59 002 848 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 25.
# -----------------------------
# Локация: Одинцово
# Вид недвижимости: house
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175578&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 1 264 685 532 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Новых обьявлений не найдено
# -----------------------------
# -----------------------------
# Локация: Одинцово
# Вид недвижимости: townhouse
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175578&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 25. Progress ratio: 100 %. Average price: 257 808 925 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 25.
# -----------------------------
# Найдено новых обьявлений: 5
# -----------------------------
# parsed pages: 2
# timeout: 108
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175578&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 25. Progress ratio: 100 %. Average price: 257 808 925 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 25.
# -----------------------------
# Локация: Домодедово
# Вид недвижимости: house
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174640&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 35 269 926 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Найдено новых обьявлений: 4
# -----------------------------
# parsed pages: 3
# timeout: 112
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174640&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>        ] 86% | Count of all parsed: 24. Progress ratio: 86 %. Average price: 32 671 868 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>  ] 97% | Count of all parsed: 27. Progress ratio: 97 %. Average price: 35 396 705 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>  ] 97% | Count of all parsed: 29. Progress ratio: 104 %. Average price: 35 742 703 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://domodedovo.cian.ru/sale/suburban/300767835/
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 29.
# -----------------------------
# Локация: Домодедово
# Вид недвижимости: townhouse
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174640&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 25. Progress ratio: 100 %. Average price: 53 488 867 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 25.
# -----------------------------
# Найдено новых обьявлений: 7
# -----------------------------
# parsed pages: 4
# timeout: 107
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174640&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>      ] 88% | Count of all parsed: 22. Progress ratio: 88 %. Average price: 61 646 167 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>    ] 92% | Count of all parsed: 23. Progress ratio: 92 %. Average price: 62 276 602 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>    ] 92% | Count of all parsed: 23. Progress ratio: 92 %. Average price: 62 276 602 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/suburban/299008451/
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 23.
# -----------------------------
# Локация: Реутов
# Вид недвижимости: house
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4958&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>] 100% | Count of all parsed: 4. Progress ratio: 100 %. Average price: 50 616 666 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 4.
# -----------------------------
# Новых обьявлений не найдено
# -----------------------------
# -----------------------------
# Локация: Реутов
# Вид недвижимости: townhouse
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4958&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>] 100% | Count of all parsed: 4. Progress ratio: 100 %. Average price: 31 033 333 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 4.
# -----------------------------
# Новых обьявлений не найдено
# -----------------------------
# -----------------------------
# Локация: Железнодорожный
# Вид недвижимости: house
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=None&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
#
# Exception: 500 Server Error: Internal Server Error for url: https://www.cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=None&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 0.
# -----------------------------
# Новых обьявлений не найдено
# -----------------------------
# -----------------------------
# Локация: Железнодорожный
# Вид недвижимости: townhouse
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=None&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 141 498 245 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Найдено новых обьявлений: 7
# -----------------------------
# parsed pages: 5
# timeout: 109
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=None&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>                                    ] 36% | Count of all parsed: 10. Progress ratio: 36 %. Average price: 102 167 730 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>                                        ] 29% | Count of all parsed: 13. Progress ratio: 47 %. Average price: 104 971 518 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>                                ] 43% | Count of all parsed: 16. Progress ratio: 58 %. Average price: 107 366 756 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://istra.cian.ru/sale/suburban/297560268/
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 16.
# -----------------------------
# Локация: Долгопрудный
# Вид недвижимости: house
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4738&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 60 266 789 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Найдено новых обьявлений: 2
# -----------------------------
# parsed pages: 6
# timeout: 109
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4738&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>      ] 90% | Count of all parsed: 25. Progress ratio: 90 %. Average price: 56 954 070 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>  ] 97% | Count of all parsed: 27. Progress ratio: 97 %. Average price: 59 752 503 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 60 266 789 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Локация: Долгопрудный
# Вид недвижимости: townhouse
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4738&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 25. Progress ratio: 100 %. Average price: 122 522 490 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 25.
# -----------------------------
# Найдено новых обьявлений: 2
# -----------------------------
# parsed pages: 7
# timeout: 114
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4738&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 25. Progress ratio: 100 %. Average price: 122 522 490 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 25.
# -----------------------------
# Локация: Москва
# Вид недвижимости: house
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=1&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 292 852 677 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Найдено новых обьявлений: 2
# -----------------------------
# parsed pages: 8
# timeout: 104
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=1&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>            ] 79% | Count of all parsed: 22. Progress ratio: 79 %. Average price: 277 110 972 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>                                          ] 25% | Count of all parsed: 24. Progress ratio: 86 %. Average price: 278 662 353 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>                              ] 47% | Count of all parsed: 27. Progress ratio: 97 %. Average price: 279 701 840 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/suburban/288033422/
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 27.
# -----------------------------
# Локация: Москва
# Вид недвижимости: townhouse
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=1&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 384 371 667 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Найдено новых обьявлений: 3
# -----------------------------
# parsed pages: 9
# timeout: 119
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=1&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>    ] 93% | Count of all parsed: 26. Progress ratio: 93 %. Average price: 374 121 403 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 384 375 371 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Локация: Красногорск
# Вид недвижимости: house
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175071&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 365 186 165 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Найдено новых обьявлений: 1
# -----------------------------
# parsed pages: 10
# timeout: 105
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175071&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>          ] 83% | Count of all parsed: 23. Progress ratio: 83 %. Average price: 356 923 537 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>      ] 90% | Count of all parsed: 25. Progress ratio: 90 %. Average price: 361 265 204 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 365 186 165 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Локация: Красногорск
# Вид недвижимости: townhouse
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175071&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 195 246 058 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Найдено новых обьявлений: 1
# -----------------------------
# parsed pages: 11
# timeout: 105
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175071&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>              ] 75% | Count of all parsed: 21. Progress ratio: 75 %. Average price: 169 142 474 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>          ] 83% | Count of all parsed: 23. Progress ratio: 83 %. Average price: 176 688 620 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>    ] 93% | Count of all parsed: 26. Progress ratio: 93 %. Average price: 189 691 826 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://krasnogorsk.cian.ru/sale/suburban/298940143/
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 26.
# -----------------------------
# Локация: Подольск
# Вид недвижимости: house
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4935&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 36 036 764 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Найдено новых обьявлений: 1
# -----------------------------
# parsed pages: 12
# timeout: 119
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4935&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>  ] 97% | Count of all parsed: 27. Progress ratio: 97 %. Average price: 60 491 207 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 60 775 135 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Локация: Подольск
# Вид недвижимости: townhouse
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4935&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 25. Progress ratio: 100 %. Average price: 34 666 307 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 25.
# -----------------------------
# Найдено новых обьявлений: 22
# -----------------------------
# parsed pages: 13
# timeout: 110
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4935&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>          ] 80% | Count of all parsed: 20. Progress ratio: 80 %. Average price: 33 355 834 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>          ] 80% | Count of all parsed: 20. Progress ratio: 80 %. Average price: 33 355 834 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>          ] 80% | Count of all parsed: 20. Progress ratio: 80 %. Average price: 33 355 834 rub
#
# Exception: 404 Client Error: Not Found for url: https://podolsk.cian.ru/sale/suburban/298398901/
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 20.
# -----------------------------
# Локация: Балашиха
# Вид недвижимости: house
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174292&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 115 151 784 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Найдено новых обьявлений: 3
# -----------------------------
# parsed pages: 14
# timeout: 110
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174292&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>              ] 75% | Count of all parsed: 21. Progress ratio: 75 %. Average price: 110 606 528 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>        ] 86% | Count of all parsed: 24. Progress ratio: 86 %. Average price: 112 369 259 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>    ] 93% | Count of all parsed: 26. Progress ratio: 93 %. Average price: 113 673 874 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://balashikha.cian.ru/sale/suburban/297729796/
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 26.
# -----------------------------
# Локация: Балашиха
# Вид недвижимости: townhouse
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174292&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 25. Progress ratio: 100 %. Average price: 57 443 003 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 25.
# -----------------------------
# Найдено новых обьявлений: 2
# -----------------------------
# parsed pages: 15
# timeout: 110
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174292&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>        ] 84% | Count of all parsed: 21. Progress ratio: 84 %. Average price: 54 455 731 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>        ] 84% | Count of all parsed: 21. Progress ratio: 84 %. Average price: 54 455 731 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>      ] 88% | Count of all parsed: 22. Progress ratio: 88 %. Average price: 55 314 821 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://balashikha.cian.ru/sale/suburban/284070809/
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 22.
# CPU times: total: 1min 18s
# Wall time: 1h 6min 46s

# %%
df = pd.concat(dfs).drop_duplicates().reset_index(drop=True)
df['date'] = dt.date.today()
df
# Out:
#                             author        author_type  \
# 0                      Центральное  real_estate_agent
# 1   МИРА  - городская недвижимость  real_estate_agent
# 2                     АЛЬТЕРНАТИВА  real_estate_agent
# 3                      ID 13118779            unknown
# 4                      ID 63989286  real_estate_agent
# ..                             ...                ...
# 57                     ID 56594583          homeowner
# 58                          Landis  real_estate_agent
# 59             KASKAD Недвижимость          developer
# 60             KASKAD Недвижимость          developer
# 61                             АРТ  real_estate_agent
#
#                                                   url   location deal_type  \
# 0   https://zhukovsky.cian.ru/sale/suburban/295148...  Жуковский      sale
# 1   https://ramenskoye.cian.ru/sale/suburban/29378...  Раменское      sale
# 2   https://ramenskoye.cian.ru/sale/suburban/29275...  Раменское      sale
# 3   https://ramenskoye.cian.ru/sale/suburban/29313...  Раменское      sale
# 4   https://ramenskoye.cian.ru/sale/suburban/29846...  Раменское      sale
# ..                                                ...        ...       ...
# 57   https://chekhov.cian.ru/sale/suburban/292848690/   Подольск      sale
# 58   https://podolsk.cian.ru/sale/suburban/296187870/   Подольск      sale
# 59  https://balashikha.cian.ru/sale/suburban/29988...   Балашиха      sale
# 60  https://balashikha.cian.ru/sale/suburban/29988...   Балашиха      sale
# 61  https://balashikha.cian.ru/sale/suburban/30127...   Балашиха      sale
#
#    accommodation_type suburban_type  price_per_month  commissions     price  \
# 0            suburban         house               -1            0   4595000
# 1            suburban     townhouse               -1            0  15500000
# 2            suburban     townhouse               -1            0  11000000
# 3            suburban     townhouse               -1            0  11200000
# 4            suburban     townhouse               -1            0  11450000
# ..                ...           ...              ...          ...       ...
# 57           suburban     townhouse               -1            0   5200000
# 58           suburban     townhouse               -1            0  10900000
# 59           suburban         house               -1            0  59300000
# 60           suburban         house               -1            0  39375000
# 61           suburban     townhouse               -1            0  35200000
#
#     ... sewage_system bathroom living_meters  floors_count         phone  \
# 0   ...            -1       -1         44 м²             2  +79057159228
# 1   ...            -1       -1        130 м²             2  +79153499147
# 2   ...            -1       -1      124,9 м²             1  +79166742577
# 3   ...            -1       -1      156,6 м²             2  +79856338236
# 4   ...            -1       -1        271 м²             2  +79895774735
# ..  ...           ...      ...           ...           ...           ...
# 57  ...            -1       -1         50 м²            -1  +79637256787
# 58  ...            -1       -1        120 м²             2  +79660619733
# 59  ...            -1       -1        240 м²             2  +79057493007
# 60  ...            -1       -1        240 м²             2  +79057493007
# 61  ...            -1       -1      179,3 м²             3  +79099973986
#
#     district    underground             street  house_number        date
# 0                м. Кратово                                   2024-04-26
# 1                            улица 2-я Осенняя            95  2024-04-26
# 2                            улица Гвардейская                2024-04-26
# 3                                улица Майская             5  2024-04-26
# 4                                улица Красная            94  2024-04-26
# ..       ...            ...                ...           ...         ...
# 57                                Лесная улица                2024-04-26
# 58                                                            2024-04-26
# 59                           Аптекарская улица            52  2024-04-26
# 60                           Аптекарская улица            54  2024-04-26
# 61            м. Щёлковская                                   2024-04-26
#
# [62 rows x 27 columns]

# %%
# %%chime
#
# new_df = df[[x not in old_df['url'].to_list() for x in df['url'].to_list()]]
# new_size = new_df.shape[0]
# display(new_df)
# Out:
#                             author        author_type  \
# 0                      Центральное  real_estate_agent
# 1   МИРА  - городская недвижимость  real_estate_agent
# 2                     АЛЬТЕРНАТИВА  real_estate_agent
# 3                      ID 13118779            unknown
# 4                      ID 63989286  real_estate_agent
# ..                             ...                ...
# 57                     ID 56594583          homeowner
# 58                          Landis  real_estate_agent
# 59             KASKAD Недвижимость          developer
# 60             KASKAD Недвижимость          developer
# 61                             АРТ  real_estate_agent
#
#                                                   url   location deal_type  \
# 0   https://zhukovsky.cian.ru/sale/suburban/295148...  Жуковский      sale
# 1   https://ramenskoye.cian.ru/sale/suburban/29378...  Раменское      sale
# 2   https://ramenskoye.cian.ru/sale/suburban/29275...  Раменское      sale
# 3   https://ramenskoye.cian.ru/sale/suburban/29313...  Раменское      sale
# 4   https://ramenskoye.cian.ru/sale/suburban/29846...  Раменское      sale
# ..                                                ...        ...       ...
# 57   https://chekhov.cian.ru/sale/suburban/292848690/   Подольск      sale
# 58   https://podolsk.cian.ru/sale/suburban/296187870/   Подольск      sale
# 59  https://balashikha.cian.ru/sale/suburban/29988...   Балашиха      sale
# 60  https://balashikha.cian.ru/sale/suburban/29988...   Балашиха      sale
# 61  https://balashikha.cian.ru/sale/suburban/30127...   Балашиха      sale
#
#    accommodation_type suburban_type  price_per_month  commissions     price  \
# 0            suburban         house               -1            0   4595000
# 1            suburban     townhouse               -1            0  15500000
# 2            suburban     townhouse               -1            0  11000000
# 3            suburban     townhouse               -1            0  11200000
# 4            suburban     townhouse               -1            0  11450000
# ..                ...           ...              ...          ...       ...
# 57           suburban     townhouse               -1            0   5200000
# 58           suburban     townhouse               -1            0  10900000
# 59           suburban         house               -1            0  59300000
# 60           suburban         house               -1            0  39375000
# 61           suburban     townhouse               -1            0  35200000
#
#     ... sewage_system bathroom living_meters  floors_count         phone  \
# 0   ...            -1       -1         44 м²             2  +79057159228
# 1   ...            -1       -1        130 м²             2  +79153499147
# 2   ...            -1       -1      124,9 м²             1  +79166742577
# 3   ...            -1       -1      156,6 м²             2  +79856338236
# 4   ...            -1       -1        271 м²             2  +79895774735
# ..  ...           ...      ...           ...           ...           ...
# 57  ...            -1       -1         50 м²            -1  +79637256787
# 58  ...            -1       -1        120 м²             2  +79660619733
# 59  ...            -1       -1        240 м²             2  +79057493007
# 60  ...            -1       -1        240 м²             2  +79057493007
# 61  ...            -1       -1      179,3 м²             3  +79099973986
#
#     district    underground             street  house_number        date
# 0                м. Кратово                                   2024-04-26
# 1                            улица 2-я Осенняя            95  2024-04-26
# 2                            улица Гвардейская                2024-04-26
# 3                                улица Майская             5  2024-04-26
# 4                                улица Красная            94  2024-04-26
# ..       ...            ...                ...           ...         ...
# 57                                Лесная улица                2024-04-26
# 58                                                            2024-04-26
# 59                           Аптекарская улица            52  2024-04-26
# 60                           Аптекарская улица            54  2024-04-26
# 61            м. Щёлковская                                   2024-04-26
#
# [62 rows x 27 columns]

# %%
# %%time
# %%chime

if new_df.shape[0] > 0:
    new_df['address'] = new_df[geo_cols].fillna('').apply(create_address, axis=1)

    coordinates = []
    for index, row in tqdm(new_df.iterrows(), total=new_df.shape[0]):
        coordinates.append(geocode_address(row))

    new_df['coordinates'] = coordinates

    num_missing_coords = new_df['coordinates'].isna().sum()
    num_geocoded = len(new_df) - num_missing_coords
    print(f"Количество объектов с координатами: {num_geocoded}")
    print(f"Количество объектов без координат: {num_missing_coords}")

    full_df = (pd.concat([old_df,new_df])
            .drop_duplicates(subset=['url','author'],ignore_index=True)
            .reset_index(drop=True))

    full_df.to_csv('suburban.csv',index=False)

    
    print(f'Количество новых обьялений: {new_size}')

else:
    full_df = old_df
    print('Новых обьявлений не обнаруженно')

print(f'Суммарное количество объялений: {full_df.shape[0]}')
# Out:
#   0%|          | 0/62 [00:00<?, ?it/s]
# 100%|██████████| 62/62 [03:56<00:00,  3.82s/it]
# Количество объектов с координатами: 52
# Количество объектов без координат: 10
# Количество новых обьялений: 62
# Суммарное количество объялений: 2948
# CPU times: total: 1.25 s
# Wall time: 3min 56s
