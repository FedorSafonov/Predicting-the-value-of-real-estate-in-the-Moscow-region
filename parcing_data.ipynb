# %% [markdown]
# # Описание проекта:
#
# **Мотивация:** Среди моих знакомых и родных в последнее время часто идут разговоры о недвижимости в москве,  у кого-то она есть, а кто-то планирует переезжать да и я сам хочу пресмотреть что-нибудь в МО. Поэтому решил разобраться в этой теме и используя отрытые данные построить модель оценки стоимости домов и таунхаусов (позже возможно добавлю квартиры).
#
# **Цель:** Создать модель машинного обучения для предсказания стоимости недвижимости (дома и таунхаусы) в Москве и подмосковье с использованием данных, полученных с помощью библиотеки Cianparser.
#
# **Целевая аудитория:**
#
# * Жители Москвы и московской области, владеющие недвижимостью и желающие оценить её стоимость.
# * Люди, планирующие переезд в Раменское или Жуковский и интересующиеся ценами на недвижимость.
#
# **Инструменты:**
#
# * Python
# * Библиотека Cianparser для сбора данных
# * Библиотеки машинного обучения (Scikit-learn)
# * Streamlit для создания интерактивного приложения
#
# **Ожидаемые результаты:**
#
# * Модель машинного обучения с MAPE <= 0.2, способная точно предсказывать стоимость недвижимости.
# * Интерактивное приложение Streamlit, позволяющее пользователям вводить характеристики недвижимости и получать прогноз цены.

# %% [markdown]
# ## Парсинг данных

# %%
import time
import chime
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
import cianparser
import requests
import re

chime.theme('mario')
# %load_ext chime

# %%
locs = pd.DataFrame(cianparser.list_locations()) 
locs.columns = ['Город','Индекс']

# %%
locs[locs['Город'] == 'Красногорск']
# Out:
#            Город  Индекс
# 126  Красногорск  175071

# %%
locations = ['Жуковский','Раменское','Одинцово','Домодедово',
            'Реутов','Железнодорожный','Долгопрудный','Москва',
            'Красногорск','Подольск','Балашиха']

# %%
def parce_suburban(city, suburban_types = ["house",'townhouse'], pages_ranges = [[1,1],[1,1]],
                   parsed_pages=0,return_counter=False,old_df=pd.read_csv('suburban.csv')):
    
    parser = cianparser.CianParser(location=city)
    data = []

    for suburban_type,pages_range in zip(suburban_types,pages_ranges):
        for page in range(pages_range[0], pages_range[1]+1):

            # Проверка есть-ли новые ссылки
            fast_suburban_sale = pd.DataFrame(parser.get_suburban( 
                                                deal_type="sale",
                                                suburban_type = suburban_type,
                                                additional_settings={"start_page":page,
                                                                    "end_page":page}
                                                ))
            
            ids = [x not in old_df['url'].to_list() for x in fast_suburban_sale['url'].to_list()]
            new_df = fast_suburban_sale[ids]
            new_size = new_df.shape[0]

            # Если есть, то скачивается страница с новыми данными
            if new_size > 0:
                print(f'Найдено {new_size} новых обьявлений')
                if parsed_pages >= 2:
                    num = np.random.randint(100,120)
                    print(f'parsed pages: {parsed_pages}')
                    print(f'timeout: {num}')
                    time.sleep(num)
                    
                suburban_sale = parser.get_suburban( 
                                                    deal_type="sale",
                                                    suburban_type = suburban_type,
                                                    with_extra_data=True,
                                                    additional_settings={"start_page":page,
                                                                        "end_page":page}
                                                    )
                data.append(pd.DataFrame(suburban_sale)[ids])
                parsed_pages +=1
            else:
                print(f'Новых обьявлений не найдено')
                pass

    # Список словарей из полученных данных преобразется в датафрейм

    df = pd.concat(data).drop_duplicates().reset_index(drop=True)

    if return_counter:
        return df,parsed_pages
    else:
        return df

# %%
parser = cianparser.CianParser(location=locations[0])
fast_suburban_sale = pd.DataFrame(parser.get_suburban( 
                                    deal_type="sale",
                                    suburban_type = 'house',
                                    additional_settings={"start_page":1,
                                                        "end_page":1}
                                    ))
# Out:
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4750&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 34 404 103 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.

# %%
pd.read_csv('suburban.csv')['url']
# Out:
# 0       https://zhukovsky.cian.ru/sale/suburban/292484...
# 1       https://zhukovsky.cian.ru/sale/suburban/296176...
# 2       https://zhukovsky.cian.ru/sale/suburban/300268...
# 3       https://zhukovsky.cian.ru/sale/suburban/300876...
# 4       https://zhukovsky.cian.ru/sale/suburban/301007...
#                               ...
# 2807    https://balashikha.cian.ru/sale/suburban/29804...
# 2808    https://balashikha.cian.ru/sale/suburban/27295...
# 2809    https://balashikha.cian.ru/sale/suburban/29298...
# 2810    https://balashikha.cian.ru/sale/suburban/27844...
# 2811    https://balashikha.cian.ru/sale/suburban/29137...
# Name: url, Length: 2812, dtype: object

# %%
fast_suburban_sale['url']
# Out:
# 0     https://zhukovsky.cian.ru/sale/suburban/292484...
# 1     https://zhukovsky.cian.ru/sale/suburban/296176...
# 2     https://zhukovsky.cian.ru/sale/suburban/300268...
# 3     https://zhukovsky.cian.ru/sale/suburban/288756...
# 4     https://zhukovsky.cian.ru/sale/suburban/300876...
# 5     https://zhukovsky.cian.ru/sale/suburban/300773...
# 6     https://zhukovsky.cian.ru/sale/suburban/299791...
# 7     https://zhukovsky.cian.ru/sale/suburban/300995...
# 8     https://zhukovsky.cian.ru/sale/suburban/300796...
# 9     https://zhukovsky.cian.ru/sale/suburban/296661...
# 10    https://zhukovsky.cian.ru/sale/suburban/301007...
# 11    https://zhukovsky.cian.ru/sale/suburban/300095...
# 12    https://zhukovsky.cian.ru/sale/suburban/298253...
# 13    https://zhukovsky.cian.ru/sale/suburban/296731...
# 14    https://zhukovsky.cian.ru/sale/suburban/274719...
# 15    https://zhukovsky.cian.ru/sale/suburban/294108...
# 16    https://zhukovsky.cian.ru/sale/suburban/298544...
# 17    https://zhukovsky.cian.ru/sale/suburban/291247...
# 18    https://zhukovsky.cian.ru/sale/suburban/298456...
# 19    https://zhukovsky.cian.ru/sale/suburban/291149...
# 20    https://zhukovsky.cian.ru/sale/suburban/287921...
# 21    https://zhukovsky.cian.ru/sale/suburban/299461...
# 22    https://zhukovsky.cian.ru/sale/suburban/300184...
# 23    https://zhukovsky.cian.ru/sale/suburban/293417...
# 24    https://zhukovsky.cian.ru/sale/suburban/300908...
# 25    https://zhukovsky.cian.ru/sale/suburban/286769...
# 26    https://zhukovsky.cian.ru/sale/suburban/300146...
# 27    https://zhukovsky.cian.ru/sale/suburban/297762...
# Name: url, dtype: object

# %%
def parce_suburban(city, suburban_types = ["house",'townhouse'], pages_ranges = [[1,1],[1,1]],
                   parsed_pages=0,return_counter=False, old_df=pd.read_csv('suburban.csv')):
    
    parser = cianparser.CianParser(location=city)
    df = pd.DataFrame()
    data = []

    for suburban_type,pages_range in zip(suburban_types,pages_ranges):
        for page in range(pages_range[0], pages_range[1]+1):
            
            print(f'-----------------------------')
            print(f'Локация: {location}')
            print(f'Вид недвижимости: {suburban_type}')
            print()
            
            # Проверка есть-ли новые ссылки
            fast_suburban_sale = pd.DataFrame(parser.get_suburban( 
                                                deal_type="sale",
                                                suburban_type = suburban_type,
                                                additional_settings={"start_page":page,
                                                                    "end_page":page}
                                                ))
            if fast_suburban_sale.shape[0] > 0:
            
                ids = [x not in old_df['url'].to_list() for x in fast_suburban_sale['url'].to_list()]
                new_df = fast_suburban_sale[ids]
                new_size = new_df.shape[0]

                # Если есть, то скачивается страница с новыми данными
                if new_size > 0:
                    print(f'-----------------------------')
                    print(f'Найдено новых обьявлений: {new_size}')
                    print(f'-----------------------------')
                    if parsed_pages >= 2:
                        num = np.random.randint(100,120)
                        print(f'parsed pages: {parsed_pages}')
                        print(f'timeout: {num}')
                        time.sleep(num)
                        
                    suburban_sale = pd.DataFrame(parser.get_suburban( 
                                                        deal_type="sale",
                                                        suburban_type = suburban_type,
                                                        with_extra_data=True,
                                                        additional_settings={"start_page":page,
                                                                            "end_page":page}
                                                        ))
                    ids = [x not in old_df['url'].to_list() for x in suburban_sale['url'].to_list()]
                    good_sales = suburban_sale[ids]
                    
                    data.append(good_sales)
                    parsed_pages +=1
                else:
                    print(f'-----------------------------')
                    print(f'Новых обьявлений не найдено')
                    print(f'-----------------------------')
                    pass
            else:
                print(f'-----------------------------')
                print(f'Новых обьявлений не найдено')
                print(f'-----------------------------')
                pass

    # Список словарей из полученных данных преобразется в датафрейм

    if len(data) > 0:
        df = pd.concat(data).drop_duplicates().reset_index(drop=True)
    
    if return_counter:
        return df,parsed_pages
    else:
        return df

# %%
# %%time
# %%chime
dfs = []
old_df = pd.read_csv('suburban.csv')
counter = 0

for location in locations:
    
    df,counter = parce_suburban(location, parsed_pages = counter, return_counter = True,
                                old_df=old_df)
    if not df.empty:
        dfs.append(df)
# Out:
# -----------------------------
# Локация: Жуковский
# Вид недвижимости: house
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4750&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 34 404 103 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Новых обьявлений не найдено
# -----------------------------
# -----------------------------
# Локация: Жуковский
# Вид недвижимости: townhouse
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4750&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>] 100% | Count of all parsed: 3. Progress ratio: 100 %. Average price: 27 666 666 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 3.
# -----------------------------
# Найдено новых обьявлений: 1
# -----------------------------
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4750&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>] 100% | Count of all parsed: 3. Progress ratio: 100 %. Average price: 27 666 666 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 3.
# -----------------------------
# Локация: Раменское
# Вид недвижимости: house
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175758&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 49 395 260 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Найдено новых обьявлений: 1
# -----------------------------
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175758&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 49 395 260 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Локация: Раменское
# Вид недвижимости: townhouse
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175758&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 25. Progress ratio: 100 %. Average price: 59 670 614 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 25.
# -----------------------------
# Найдено новых обьявлений: 3
# -----------------------------
# parsed pages: 2
# timeout: 109
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175758&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 10. Progress ratio: 100 %. Average price: 48 926 776 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 10.
# -----------------------------
# Локация: Одинцово
# Вид недвижимости: house
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175578&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 1 305 537 433 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Найдено новых обьявлений: 4
# -----------------------------
# parsed pages: 3
# timeout: 102
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175578&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                    ] 65% | Count of all parsed: 18. Progress ratio: 65 %. Average price: 1 261 414 106 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 1 305 767 313 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Локация: Одинцово
# Вид недвижимости: townhouse
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175578&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 25. Progress ratio: 100 %. Average price: 261 511 299 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 25.
# -----------------------------
# Найдено новых обьявлений: 7
# -----------------------------
# parsed pages: 4
# timeout: 110
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175578&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 25. Progress ratio: 100 %. Average price: 261 511 299 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 25.
# -----------------------------
# Локация: Домодедово
# Вид недвижимости: house
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174640&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 44 607 596 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Найдено новых обьявлений: 12
# -----------------------------
# parsed pages: 5
# timeout: 117
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174640&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 44 607 596 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Локация: Домодедово
# Вид недвижимости: townhouse
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174640&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 25. Progress ratio: 100 %. Average price: 58 245 986 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 25.
# -----------------------------
# Найдено новых обьявлений: 8
# -----------------------------
# parsed pages: 6
# timeout: 113
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174640&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 25. Progress ratio: 100 %. Average price: 58 245 986 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 25.
# -----------------------------
# Локация: Реутов
# Вид недвижимости: house
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4958&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 9. Progress ratio: 100 %. Average price: 48 353 868 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 9.
# -----------------------------
# Найдено новых обьявлений: 4
# -----------------------------
# parsed pages: 7
# timeout: 116
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4958&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>] 100% | Count of all parsed: 5. Progress ratio: 100 %. Average price: 64 801 666 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 5.
# -----------------------------
# Локация: Реутов
# Вид недвижимости: townhouse
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4958&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>] 100% | Count of all parsed: 5. Progress ratio: 100 %. Average price: 49 146 666 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 5.
# -----------------------------
# Найдено новых обьявлений: 1
# -----------------------------
# parsed pages: 8
# timeout: 117
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4958&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>] 100% | Count of all parsed: 6. Progress ratio: 100 %. Average price: 49 761 666 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 6.
# -----------------------------
# Локация: Железнодорожный
# Вид недвижимости: house
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=None&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
#
# Exception: 500 Server Error: Internal Server Error for url: https://www.cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=None&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 0.
# -----------------------------
# Новых обьявлений не найдено
# -----------------------------
# -----------------------------
# Локация: Железнодорожный
# Вид недвижимости: townhouse
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=None&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 191 734 679 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Найдено новых обьявлений: 14
# -----------------------------
# parsed pages: 9
# timeout: 100
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=None&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>  ] 97% | Count of all parsed: 27. Progress ratio: 97 %. Average price: 124 190 082 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>  ] 97% | Count of all parsed: 27. Progress ratio: 97 %. Average price: 124 190 082 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 128 118 653 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Локация: Долгопрудный
# Вид недвижимости: house
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4738&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 61 397 920 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Найдено новых обьявлений: 3
# -----------------------------
# parsed pages: 10
# timeout: 109
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4738&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>          ] 83% | Count of all parsed: 23. Progress ratio: 83 %. Average price: 56 839 558 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>      ] 90% | Count of all parsed: 25. Progress ratio: 90 %. Average price: 57 684 921 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 61 397 920 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Локация: Долгопрудный
# Вид недвижимости: townhouse
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4738&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 25. Progress ratio: 100 %. Average price: 119 531 080 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 25.
# -----------------------------
# Найдено новых обьявлений: 4
# -----------------------------
# parsed pages: 11
# timeout: 102
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4738&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>        ] 84% | Count of all parsed: 21. Progress ratio: 84 %. Average price: 114 097 543 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>    ] 92% | Count of all parsed: 23. Progress ratio: 92 %. Average price: 116 831 080 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 25. Progress ratio: 100 %. Average price: 119 531 080 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 25.
# -----------------------------
# Локация: Москва
# Вид недвижимости: house
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=1&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 235 329 307 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Найдено новых обьявлений: 4
# -----------------------------
# parsed pages: 12
# timeout: 102
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=1&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>        ] 86% | Count of all parsed: 24. Progress ratio: 86 %. Average price: 294 018 406 rub
#  1 | 1 page with list: [=>=>=>=>=>                                              ] 18% | Count of all parsed: 26. Progress ratio: 93 %. Average price: 294 481 390 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>                                  ] 40% | Count of all parsed: 29. Progress ratio: 104 %. Average price: 295 621 642 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/suburban/300779720/
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 29.
# -----------------------------
# Локация: Москва
# Вид недвижимости: townhouse
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=1&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 366 346 469 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Найдено новых обьявлений: 3
# -----------------------------
# parsed pages: 13
# timeout: 112
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=1&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 366 346 469 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Локация: Красногорск
# Вид недвижимости: house
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175071&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 390 266 438 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Найдено новых обьявлений: 1
# -----------------------------
# parsed pages: 14
# timeout: 102
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175071&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>      ] 90% | Count of all parsed: 25. Progress ratio: 90 %. Average price: 340 428 579 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 345 447 260 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Локация: Красногорск
# Вид недвижимости: townhouse
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175071&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 193 716 995 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Найдено новых обьявлений: 4
# -----------------------------
# parsed pages: 15
# timeout: 112
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175071&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>          ] 83% | Count of all parsed: 23. Progress ratio: 83 %. Average price: 182 216 773 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>      ] 90% | Count of all parsed: 25. Progress ratio: 90 %. Average price: 185 893 857 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 193 716 995 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Локация: Подольск
# Вид недвижимости: house
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4935&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 55 022 349 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Найдено новых обьявлений: 2
# -----------------------------
# parsed pages: 16
# timeout: 118
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4935&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>  ] 97% | Count of all parsed: 27. Progress ratio: 97 %. Average price: 54 695 563 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 55 022 349 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Локация: Подольск
# Вид недвижимости: townhouse
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4935&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>] 100% | Count of all parsed: 1. Progress ratio: 100 %. Average price: 13 100 000 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 1.
# -----------------------------
# Найдено новых обьявлений: 1
# -----------------------------
# parsed pages: 17
# timeout: 116
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4935&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>] 100% | Count of all parsed: 1. Progress ratio: 100 %. Average price: 13 100 000 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 1.
# -----------------------------
# Локация: Балашиха
# Вид недвижимости: house
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174292&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 128 133 753 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Найдено новых обьявлений: 6
# -----------------------------
# parsed pages: 18
# timeout: 110
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174292&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 128 133 753 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# -----------------------------
# Локация: Балашиха
# Вид недвижимости: townhouse
#
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174292&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 25. Progress ratio: 100 %. Average price: 54 647 721 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 25.
# -----------------------------
# Найдено новых обьявлений: 3
# -----------------------------
# parsed pages: 19
# timeout: 114
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174292&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 25. Progress ratio: 100 %. Average price: 54 647 721 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 25.
# CPU times: total: 1min 19s
# Wall time: 1h 15min 15s

# %%
df = pd.concat(dfs).drop_duplicates().reset_index(drop=True)
df['date'] = dt.date.today()
df
# Out:
#                          author        author_type  \
# 0                     ID 461204          homeowner
# 1                  Кредит Центр  real_estate_agent
# 2   BARNES International Realty  real_estate_agent
# 3                   ID 76943077            unknown
# 4                   FS PROPERTY  real_estate_agent
# ..                          ...                ...
# 70                 ЕГСН Продажа  real_estate_agent
# 71                  Гарант плюс  real_estate_agent
# 72                         ОГРК  real_estate_agent
# 73                Сания Галиева            realtor
# 74          Владимир Дворянский            realtor
#
#                                                   url   location deal_type  \
# 0   https://odintsovo.cian.ru/sale/suburban/300340...  Жуковский      sale
# 1   https://ramenskoye.cian.ru/sale/suburban/29951...  Раменское      sale
# 2   https://odintsovo.cian.ru/sale/suburban/292072...   Одинцово      sale
# 3   https://odintsovo.cian.ru/sale/suburban/278034...   Одинцово      sale
# 4   https://odintsovo.cian.ru/sale/suburban/219764...   Одинцово      sale
# ..                                                ...        ...       ...
# 70  https://balashikha.cian.ru/sale/suburban/30112...   Балашиха      sale
# 71  https://balashikha.cian.ru/sale/suburban/28937...   Балашиха      sale
# 72  https://balashikha.cian.ru/sale/suburban/30087...   Балашиха      sale
# 73  https://balashikha.cian.ru/sale/suburban/29976...   Балашиха      sale
# 74  https://balashikha.cian.ru/sale/suburban/29855...   Балашиха      sale
#
#    accommodation_type suburban_type  price_per_month  commissions      price  \
# 0            suburban     townhouse               -1            0   35000000
# 1            suburban         house               -1            0    8900000
# 2            suburban         house               -1            0  146354523
# 3            suburban         house               -1            0   43700000
# 4            suburban         house               -1            0  513104899
# ..                ...           ...              ...          ...        ...
# 70           suburban         house               -1            0   25700000
# 71           suburban         house               -1            0   23000000
# 72           suburban     townhouse               -1            0    9800000
# 73           suburban     townhouse               -1            0   18900000
# 74           suburban     townhouse               -1            0   15900000
#
#     ... sewage_system bathroom living_meters  floors_count         phone  \
# 0   ...            -1       -1        150 м²             2  +79850012066
# 1   ...            -1       -1      133,8 м²             2  +79660617340
# 2   ...            -1       -1        700 м²             2  +79623650297
# 3   ...            -1       -1            -1             2  +79660624795
# 4   ...            -1       -1            -1            -1  +79175790370
# ..  ...           ...      ...           ...           ...           ...
# 70  ...            -1       -1        168 м²             2  +79645647890
# 71  ...            -1       -1        286 м²             2  +79647220890
# 72  ...            -1       -1        220 м²             2  +79672089940
# 73  ...            -1       -1        180 м²            -1  +79165625420
# 74  ...            -1       -1      164,9 м²             2  +79154345480
#
#            district         underground                  street  house_number  \
# 0                                                Вишневая улица
# 1   р-н Центральный        м. Раменское
# 2                          м. Мичуринец  Баковка-Набережная ДНТ            1В
# 3                           м. Одинцово
# 4
# ..              ...                 ...                     ...           ...
# 70                            м. Кучино      Коллективная улица          165Б
# 71                   м. Железнодорожная        улица Лермонтова            30
# 72
# 73                                                улица Садовая            42
# 74                                               улица Троицкая            20
#
#           date
# 0   2024-04-25
# 1   2024-04-25
# 2   2024-04-25
# 3   2024-04-25
# 4   2024-04-25
# ..         ...
# 70  2024-04-25
# 71  2024-04-25
# 72  2024-04-25
# 73  2024-04-25
# 74  2024-04-25
#
# [75 rows x 27 columns]

# %%
# %%chime
#
# new_df = df[[x not in old_df['url'].to_list() for x in df['url'].to_list()]]
# new_size = new_df.shape[0]
# display(new_df)
# Out:
#                          author        author_type  \
# 0                     ID 461204          homeowner
# 1                  Кредит Центр  real_estate_agent
# 2   BARNES International Realty  real_estate_agent
# 3                   ID 76943077            unknown
# 4                   FS PROPERTY  real_estate_agent
# ..                          ...                ...
# 70                 ЕГСН Продажа  real_estate_agent
# 71                  Гарант плюс  real_estate_agent
# 72                         ОГРК  real_estate_agent
# 73                Сания Галиева            realtor
# 74          Владимир Дворянский            realtor
#
#                                                   url   location deal_type  \
# 0   https://odintsovo.cian.ru/sale/suburban/300340...  Жуковский      sale
# 1   https://ramenskoye.cian.ru/sale/suburban/29951...  Раменское      sale
# 2   https://odintsovo.cian.ru/sale/suburban/292072...   Одинцово      sale
# 3   https://odintsovo.cian.ru/sale/suburban/278034...   Одинцово      sale
# 4   https://odintsovo.cian.ru/sale/suburban/219764...   Одинцово      sale
# ..                                                ...        ...       ...
# 70  https://balashikha.cian.ru/sale/suburban/30112...   Балашиха      sale
# 71  https://balashikha.cian.ru/sale/suburban/28937...   Балашиха      sale
# 72  https://balashikha.cian.ru/sale/suburban/30087...   Балашиха      sale
# 73  https://balashikha.cian.ru/sale/suburban/29976...   Балашиха      sale
# 74  https://balashikha.cian.ru/sale/suburban/29855...   Балашиха      sale
#
#    accommodation_type suburban_type  price_per_month  commissions      price  \
# 0            suburban     townhouse               -1            0   35000000
# 1            suburban         house               -1            0    8900000
# 2            suburban         house               -1            0  146354523
# 3            suburban         house               -1            0   43700000
# 4            suburban         house               -1            0  513104899
# ..                ...           ...              ...          ...        ...
# 70           suburban         house               -1            0   25700000
# 71           suburban         house               -1            0   23000000
# 72           suburban     townhouse               -1            0    9800000
# 73           suburban     townhouse               -1            0   18900000
# 74           suburban     townhouse               -1            0   15900000
#
#     ... sewage_system bathroom living_meters  floors_count         phone  \
# 0   ...            -1       -1        150 м²             2  +79850012066
# 1   ...            -1       -1      133,8 м²             2  +79660617340
# 2   ...            -1       -1        700 м²             2  +79623650297
# 3   ...            -1       -1            -1             2  +79660624795
# 4   ...            -1       -1            -1            -1  +79175790370
# ..  ...           ...      ...           ...           ...           ...
# 70  ...            -1       -1        168 м²             2  +79645647890
# 71  ...            -1       -1        286 м²             2  +79647220890
# 72  ...            -1       -1        220 м²             2  +79672089940
# 73  ...            -1       -1        180 м²            -1  +79165625420
# 74  ...            -1       -1      164,9 м²             2  +79154345480
#
#            district         underground                  street  house_number  \
# 0                                                Вишневая улица
# 1   р-н Центральный        м. Раменское
# 2                          м. Мичуринец  Баковка-Набережная ДНТ            1В
# 3                           м. Одинцово
# 4
# ..              ...                 ...                     ...           ...
# 70                            м. Кучино      Коллективная улица          165Б
# 71                   м. Железнодорожная        улица Лермонтова            30
# 72
# 73                                                улица Садовая            42
# 74                                               улица Троицкая            20
#
#           date
# 0   2024-04-25
# 1   2024-04-25
# 2   2024-04-25
# 3   2024-04-25
# 4   2024-04-25
# ..         ...
# 70  2024-04-25
# 71  2024-04-25
# 72  2024-04-25
# 73  2024-04-25
# 74  2024-04-25
#
# [75 rows x 27 columns]

# %%
if new_df.shape[0] > 0:
    full_df = (pd.concat([old_df,new_df])
            .drop_duplicates(subset=['url','author'],ignore_index=True)
            .reset_index(drop=True))

    full_df.to_csv('suburban.csv',index=False)

    
    print(f'Количество новых обьялений: {new_size}')

else:
    print('Новых обьявлений не обнаруженно')

print(f'Суммарное количество объялений: {full_df.shape[0]}')
# Out:
# Количество новых обьялений: 75
# Суммарное количество объялений: 2886

# %%
from geopy.geocoders import Nominatim
from geopy.distance import geodesic

# %%
geolocator = Nominatim(user_agent="my_app")

moscow_center = geolocator.geocode("Москва, центр")
moscow_coords = (moscow_center.latitude, moscow_center.longitude)

# %%
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="my_app")  # user_agent нужен для идентификации приложения

# Получение координат центра Москвы
moscow_location = geolocator.geocode("Москва, Россия")
moscow_coords = (moscow_location.latitude, moscow_location.longitude)

# Получение координат центра Раменского
ramenskoye_location = geolocator.geocode("Раменское, Московская область, Россия")
ramenskoye_coords = (ramenskoye_location.latitude, ramenskoye_location.longitude)

# Получение координат центра Жуковского
zhukovsky_location = geolocator.geocode("Жуковский, Московская область, Россия")
zhukovsky_coords = (zhukovsky_location.latitude, zhukovsky_location.longitude)

# Пример геокодирования объекта недвижимости
address = "улица Ленина, 10, Раменское район, Московская область, Россия"
location = geolocator.geocode(address)
property_coords = (location.latitude, location.longitude)

# %%
location
# Out:
# Location(улица Ленина, Красный Октябрь, Раменское, Раменский городской округ, Московская область, Центральный федеральный округ, 140104, Россия, (55.5799671, 38.1908862, 0.0))

# %%
zhukovsky_coords
# Out:
# (55.5972801, 38.1199863)

# %%
property_coords
# Out:
# (55.5799671, 38.1908862)
