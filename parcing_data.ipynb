# %% [markdown]
# # Описание проекта:
#
# **Мотивация:** Среди моих знакомых и родных в последнее время часто идут разговоры о недвижимости в москве,  у кого-то она есть, а кто-то планирует переезжать да и я сам хочу пресмотреть что-нибудь в МО. Поэтому решил разобраться в этой теме и используя отрытые данные построить модель оценки стоимости домов и таунхаусов (позже возможно добавлю квартиры).
#
# **Цель:** Создать модель машинного обучения для предсказания стоимости недвижимости (дома и таунхаусы) в Москве и подмосковье с использованием данных, полученных с помощью библиотеки Cianparser.
#
# **Целевая аудитория:**
#
# * Жители Москвы и московской области, владеющие недвижимостью и желающие оценить её стоимость.
# * Люди, планирующие переезд в Раменское или Жуковский и интересующиеся ценами на недвижимость.
#
# **Инструменты:**
#
# * Python
# * Библиотека Cianparser для сбора данных
# * Библиотеки машинного обучения (Scikit-learn)
# * Streamlit для создания интерактивного приложения
#
# **Ожидаемые результаты:**
#
# * Модель машинного обучения с MAPE <= 0.2, способная точно предсказывать стоимость недвижимости.
# * Интерактивное приложение Streamlit, позволяющее пользователям вводить характеристики недвижимости и получать прогноз цены.

# %% [markdown]
# ## Парсинг данных

# %%
import time
import chime
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
import cianparser
import requests
import re

chime.theme('mario')
# %load_ext chime

# %%
locs = pd.DataFrame(cianparser.list_locations()) 
locs.columns = ['Город','Индекс']

# %%
locs[locs['Город'] == 'Красногорск']
# Out:
#            Город  Индекс
# 126  Красногорск  175071

# %%
locations = ['Жуковский','Раменское','Одинцово','Домодедово',
            'Реутов','Железнодорожный','Долгопрудный','Москва',
            'Красногорск','Подольск','Балашиха']

# %%
def parce_suburban(city, suburban_types = ["house",'townhouse'], pages_counts = [[1,1]],parsed_pages=0):
    parser = cianparser.CianParser(location=city)

    data = []

    for suburban_type,pages_count in zip(suburban_types,pages_counts):
        for page in range(pages_count[0], pages_count[1]+1):
            if parsed_pages >= 2:
                num = np.random.randint(110,120)
                print(f'parsed pages: {parsed_pages}')
                print(f'timeout: {num}')
                time.sleep(num)
                
            suburban_sale = parser.get_suburban( 
                                                deal_type="sale",
                                                suburban_type = suburban_type,
                                                with_extra_data=True,
                                                additional_settings={"start_page":page,
                                                                    "end_page":page}
                                                )
            data.append(pd.DataFrame(suburban_sale))
            parsed_pages +=1

    df = pd.concat(data).drop_duplicates().reset_index(drop=True)
    return df

# %%
# %%time
# %%chime
dfs = []

for parsed_pages,location in enumerate(locations):
    
    df = parce_suburban(location, pages_counts = [[1,1],[1,1]],
                        parsed_pages = parsed_pages*2)
    dfs.append(df)
# Out:
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4750&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 35 749 242 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4750&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>] 100% | Count of all parsed: 6. Progress ratio: 100 %. Average price: 36 770 833 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 6.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175758&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                        ] 58% | Count of all parsed: 16. Progress ratio: 58 %. Average price: 41 170 519 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                    ] 65% | Count of all parsed: 18. Progress ratio: 65 %. Average price: 42 258 427 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                ] 72% | Count of all parsed: 20. Progress ratio: 72 %. Average price: 43 516 322 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://ramenskoye.cian.ru/sale/suburban/300028091/
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 20.
# parsed pages: 2
# timeout: 111
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175758&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>      ] 88% | Count of all parsed: 22. Progress ratio: 88 %. Average price: 58 334 398 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>  ] 96% | Count of all parsed: 24. Progress ratio: 96 %. Average price: 59 282 586 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 25. Progress ratio: 100 %. Average price: 59 762 586 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 25.
# parsed pages: 2
# timeout: 119
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175578&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>      ] 90% | Count of all parsed: 25. Progress ratio: 90 %. Average price: 1 222 285 056 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>  ] 97% | Count of all parsed: 27. Progress ratio: 97 %. Average price: 1 225 133 774 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 1 226 901 632 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# parsed pages: 3
# timeout: 106
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175578&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>      ] 88% | Count of all parsed: 22. Progress ratio: 88 %. Average price: 265 515 575 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>  ] 96% | Count of all parsed: 24. Progress ratio: 96 %. Average price: 268 799 995 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>  ] 96% | Count of all parsed: 24. Progress ratio: 96 %. Average price: 268 799 995 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/suburban/278926722/
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 24.
# parsed pages: 3
# timeout: 92
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174640&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                  ] 68% | Count of all parsed: 19. Progress ratio: 68 %. Average price: 27 308 728 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>            ] 79% | Count of all parsed: 22. Progress ratio: 79 %. Average price: 30 588 480 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>        ] 86% | Count of all parsed: 24. Progress ratio: 86 %. Average price: 31 482 422 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://domodedovo.cian.ru/sale/suburban/294597772/
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 24.
# parsed pages: 4
# timeout: 114
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174640&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>          ] 80% | Count of all parsed: 20. Progress ratio: 80 %. Average price: 58 166 789 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>        ] 84% | Count of all parsed: 21. Progress ratio: 84 %. Average price: 58 832 980 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>        ] 84% | Count of all parsed: 21. Progress ratio: 84 %. Average price: 58 832 980 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/suburban/293621281/
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 21.
# parsed pages: 4
# timeout: 119
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4958&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>] 100% | Count of all parsed: 2. Progress ratio: 100 %. Average price: 18 400 000 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 2.
# parsed pages: 5
# timeout: 107
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4958&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>] 100% | Count of all parsed: 5. Progress ratio: 100 %. Average price: 25 940 000 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 5.
# parsed pages: 5
# timeout: 99
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=None&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
#
# Exception: 500 Server Error: Internal Server Error for url: https://www.cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=None&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 0.
# parsed pages: 6
# timeout: 119
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=None&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 136 003 597 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# parsed pages: 6
# timeout: 109
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4738&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>      ] 90% | Count of all parsed: 25. Progress ratio: 90 %. Average price: 57 861 112 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>  ] 97% | Count of all parsed: 27. Progress ratio: 97 %. Average price: 60 455 842 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 60 970 127 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# parsed pages: 7
# timeout: 94
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4738&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>    ] 92% | Count of all parsed: 21. Progress ratio: 92 %. Average price: 115 373 964 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 23. Progress ratio: 100 %. Average price: 118 496 494 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 23.
# parsed pages: 7
# timeout: 105
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=1&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>              ] 75% | Count of all parsed: 21. Progress ratio: 75 %. Average price: 199 914 279 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>        ] 86% | Count of all parsed: 24. Progress ratio: 86 %. Average price: 208 774 901 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                          ] 54% | Count of all parsed: 26. Progress ratio: 93 %. Average price: 221 890 286 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/suburban/298718828/
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 26.
# parsed pages: 8
# timeout: 106
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=1&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>          ] 83% | Count of all parsed: 23. Progress ratio: 83 %. Average price: 350 660 008 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>    ] 93% | Count of all parsed: 26. Progress ratio: 93 %. Average price: 354 117 142 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 355 351 931 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# CPU times: total: 1min 7s
# Wall time: 54min 36s

# %%
locs[locs['Город']=='Балашиха']
# Out:
#         Город  Индекс
# 109  Балашиха  174292

# %%
# %%time
# %%chime

dfs = []

dfs.append(parce_suburban('Подольск', pages_counts = [[1,4]],suburban_types=['house'],
                            parsed_pages = 0))

dfs.append(parce_suburban('Красногорск', pages_counts = [[1,4],[1,2]],
                    parsed_pages = 4))

dfs.append(parce_suburban('Балашиха', pages_counts = [[1,8],[1,1]],
                    parsed_pages = 10))
# Out:
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4935&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 49 221 489 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=2&with_neighbors=0&region=4935&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                ] 72% | Count of all parsed: 20. Progress ratio: 72 %. Average price: 29 316 876 rub
#
# Exception: ('Connection aborted.', TimeoutError(10060, 'Попытка установить соединение была безуспешной, т.к. от другого компьютера за требуемое время не получен нужный отклик, или было разорвано уже установленное соединение из-за неверного отклика уже подключенного компьютера', None, 10060, None))
# The collection of information from the pages with ending parse on 2 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 20.
# parsed pages: 2
# timeout: 107
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=3&with_neighbors=0&region=4935&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#
#  1 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 70 210 408 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# parsed pages: 3
# timeout: 106
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=4&with_neighbors=0&region=4935&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 4 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 25. Progress ratio: 100 %. Average price: 93 746 170 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 25.
# parsed pages: 4
# timeout: 104
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175071&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 346 220 422 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# parsed pages: 5
# timeout: 112
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=2&with_neighbors=0&region=175071&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 642 774 548 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# parsed pages: 6
# timeout: 106
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=3&with_neighbors=0&region=175071&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                ] 68% | Count of all parsed: 17. Progress ratio: 68 %. Average price: 455 715 575 rub
#  1 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>                          ] 48% | Count of all parsed: 18. Progress ratio: 72 %. Average price: 458 487 797 rub
#  1 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>                          ] 48% | Count of all parsed: 18. Progress ratio: 72 %. Average price: 458 487 797 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/suburban/247142110/
# The collection of information from the pages with ending parse on 3 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 18.
# parsed pages: 7
# timeout: 101
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=4&with_neighbors=0&region=175071&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 4 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>            ] 79% | Count of all parsed: 22. Progress ratio: 79 %. Average price: 327 037 185 rub
#  1 | 4 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>        ] 86% | Count of all parsed: 24. Progress ratio: 86 %. Average price: 329 719 250 rub
#  1 | 4 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>  ] 97% | Count of all parsed: 27. Progress ratio: 97 %. Average price: 334 484 806 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://krasnogorsk.cian.ru/sale/suburban/298806637/
# The collection of information from the pages with ending parse on 4 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 27.
# parsed pages: 8
# timeout: 93
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175071&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                ] 72% | Count of all parsed: 20. Progress ratio: 72 %. Average price: 183 632 905 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>            ] 79% | Count of all parsed: 22. Progress ratio: 79 %. Average price: 186 978 143 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>      ] 90% | Count of all parsed: 25. Progress ratio: 90 %. Average price: 192 156 288 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://krasnogorsk.cian.ru/sale/suburban/294291321/
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 25.
# parsed pages: 9
# timeout: 109
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=2&with_neighbors=0&region=175071&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>                        ] 52% | Count of all parsed: 13. Progress ratio: 52 %. Average price: 308 020 096 rub
#  1 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>                        ] 52% | Count of all parsed: 13. Progress ratio: 52 %. Average price: 308 020 096 rub
#  1 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>                        ] 52% | Count of all parsed: 13. Progress ratio: 52 %. Average price: 308 020 096 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/suburban/297614399/
# The collection of information from the pages with ending parse on 2 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 13.
# parsed pages: 10
# timeout: 92
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174292&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                ] 72% | Count of all parsed: 20. Progress ratio: 72 %. Average price: 89 227 678 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>            ] 79% | Count of all parsed: 22. Progress ratio: 79 %. Average price: 94 920 319 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>        ] 86% | Count of all parsed: 24. Progress ratio: 86 %. Average price: 97 397 674 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://balashikha.cian.ru/sale/suburban/289378997/
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 24.
# parsed pages: 11
# timeout: 90
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=2&with_neighbors=0&region=174292&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                  ] 68% | Count of all parsed: 19. Progress ratio: 68 %. Average price: 85 611 375 rub
#  1 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>            ] 79% | Count of all parsed: 22. Progress ratio: 79 %. Average price: 86 926 202 rub
#  1 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>        ] 86% | Count of all parsed: 24. Progress ratio: 86 %. Average price: 88 406 274 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://balashikha.cian.ru/sale/suburban/283335121/
# The collection of information from the pages with ending parse on 2 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 24.
# parsed pages: 12
# timeout: 101
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=3&with_neighbors=0&region=174292&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>              ] 75% | Count of all parsed: 21. Progress ratio: 75 %. Average price: 52 410 221 rub
#  1 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>          ] 83% | Count of all parsed: 23. Progress ratio: 83 %. Average price: 56 685 260 rub
#  1 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>    ] 93% | Count of all parsed: 26. Progress ratio: 93 %. Average price: 59 162 376 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://balashikha.cian.ru/sale/suburban/297465534/
# The collection of information from the pages with ending parse on 3 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 26.
# parsed pages: 13
# timeout: 113
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=4&with_neighbors=0&region=174292&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 4 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>          ] 83% | Count of all parsed: 23. Progress ratio: 83 %. Average price: 70 670 337 rub
#  1 | 4 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>    ] 93% | Count of all parsed: 26. Progress ratio: 93 %. Average price: 72 812 709 rub
#  1 | 4 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 74 639 428 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# parsed pages: 14
# timeout: 103
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=5&with_neighbors=0&region=174292&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 5 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                ] 72% | Count of all parsed: 20. Progress ratio: 72 %. Average price: 96 289 957 rub
#  1 | 5 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>            ] 79% | Count of all parsed: 22. Progress ratio: 79 %. Average price: 99 705 346 rub
#  1 | 5 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>        ] 86% | Count of all parsed: 24. Progress ratio: 86 %. Average price: 101 564 042 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://balashikha.cian.ru/sale/suburban/289273077/
# The collection of information from the pages with ending parse on 5 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 24.
# parsed pages: 15
# timeout: 107
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=6&with_neighbors=0&region=174292&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 6 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>            ] 79% | Count of all parsed: 22. Progress ratio: 79 %. Average price: 171 708 986 rub
#  1 | 6 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>        ] 86% | Count of all parsed: 25. Progress ratio: 90 %. Average price: 174 756 450 rub
#  1 | 6 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>    ] 93% | Count of all parsed: 27. Progress ratio: 97 %. Average price: 176 482 945 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://balashikha.cian.ru/sale/suburban/295990730/
# The collection of information from the pages with ending parse on 6 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 27.
# parsed pages: 16
# timeout: 91
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=7&with_neighbors=0&region=174292&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 7 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                  ] 68% | Count of all parsed: 19. Progress ratio: 68 %. Average price: 152 364 270 rub
#  1 | 7 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>              ] 75% | Count of all parsed: 22. Progress ratio: 79 %. Average price: 158 794 741 rub
#  1 | 7 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>          ] 83% | Count of all parsed: 24. Progress ratio: 86 %. Average price: 161 990 394 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://balashikha.cian.ru/sale/suburban/300951290/
# The collection of information from the pages with ending parse on 7 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 24.
# parsed pages: 17
# timeout: 117
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=8&with_neighbors=0&region=174292&deal_type=sale&offer_type=suburban&object_type%5B0%5D=1
#
# Collecting information from pages with list of offers
#  1 | 8 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>        ] 86% | Count of all parsed: 24. Progress ratio: 86 %. Average price: 165 595 888 rub
#  1 | 8 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>  ] 97% | Count of all parsed: 27. Progress ratio: 97 %. Average price: 173 998 509 rub
#  1 | 8 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 175 137 795 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
# parsed pages: 18
# timeout: 91
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174292&deal_type=sale&offer_type=suburban&object_type%5B0%5D=4
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>              ] 72% | Count of all parsed: 18. Progress ratio: 72 %. Average price: 50 546 703 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>              ] 72% | Count of all parsed: 18. Progress ratio: 72 %. Average price: 50 546 703 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>            ] 76% | Count of all parsed: 19. Progress ratio: 76 %. Average price: 51 220 387 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://balashikha.cian.ru/sale/suburban/294567642/
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 19.
# CPU times: total: 1min 13s
# Wall time: 1h 14min 58s

# %%
df = pd.concat(dfs).drop_duplicates().reset_index(drop=True)
df['date'] = dt.date.today()
df
# Out:
#                               author        author_type  \
# 0                    Монолит Столица  real_estate_agent
# 1                        ID 87392027            unknown
# 2                           ID 53733            realtor
# 3                     ЭТАЖИ Подольск  real_estate_agent
# 4                     ЭТАЖИ Подольск  real_estate_agent
# ..                               ...                ...
# 425                      Home Market  real_estate_agent
# 426                 Светлана Заремба            realtor
# 427               Гульнара Абдуллина            realtor
# 428  АН Мегаполис-Сервис Юбилейная 8  real_estate_agent
# 429                  Михаил Максимов            realtor
#
#                                                    url  location deal_type  \
# 0     https://podolsk.cian.ru/sale/suburban/299274329/  Подольск      sale
# 1     https://podolsk.cian.ru/sale/suburban/300560807/  Подольск      sale
# 2     https://podolsk.cian.ru/sale/suburban/300899069/  Подольск      sale
# 3     https://podolsk.cian.ru/sale/suburban/299302858/  Подольск      sale
# 4     https://podolsk.cian.ru/sale/suburban/298492436/  Подольск      sale
# ..                                                 ...       ...       ...
# 425  https://balashikha.cian.ru/sale/suburban/29298...  Балашиха      sale
# 426  https://balashikha.cian.ru/sale/suburban/27844...  Балашиха      sale
# 427  https://balashikha.cian.ru/sale/suburban/28407...  Балашиха      sale
# 428  https://balashikha.cian.ru/sale/suburban/30068...  Балашиха      sale
# 429  https://balashikha.cian.ru/sale/suburban/29137...  Балашиха      sale
#
#     accommodation_type suburban_type  price_per_month  commissions     price  \
# 0             suburban         house               -1            0  12500000
# 1             suburban         house               -1            0  25000000
# 2             suburban         house               -1            0   1900000
# 3             suburban         house               -1            0  11000000
# 4             suburban         house               -1            0   8500000
# ..                 ...           ...              ...          ...       ...
# 425           suburban     townhouse               -1            0  26500000
# 426           suburban     townhouse               -1            0  27499000
# 427           suburban     townhouse               -1            0  17350000
# 428           suburban     townhouse               -1            0  14990000
# 429           suburban     townhouse               -1            0  12800000
#
#      ... sewage_system bathroom living_meters floors_count         phone  \
# 0    ...            -1       -1       85,1 м²            2  +79651405728
# 1    ...            -1       -1        185 м²            2  +79851813193
# 2    ...            -1       -1         52 м²            2  +79683348903
# 3    ...            -1       -1         62 м²            2  +79684552495
# 4    ...            -1       -1        200 м²            3  +79645599647
# ..   ...           ...      ...           ...          ...           ...
# 425  ...            -1       -1      229,6 м²            3  +79660505643
# 426  ...            -1       -1        260 м²            3  +79623689260
# 427  ...            -1       -1            -1            2  +79167257220
# 428  ...            -1       -1       85,5 м²            2  +79684988072
# 429  ...            -1       -1        166 м²            3  +79175096261
#
#      district      underground                   street  house_number  \
# 0                  м. Подольск        переулок Крымский          2/27
# 1                  м. Подольск  улица Малая Северовская            20
# 2                  м. Подольск       улица Коммунальная
# 3                м. Силикатная         Силикатная улица
# 4                  м. Подольск  улица Малая Зеленовская
# ..        ...              ...                      ...           ...
# 425                                    шоссе Леоновское           6к7
# 426                                      улица Студеная
# 427            м. Салтыковская          Граничная улица            14
# 428            м. Салтыковская           улица Рудневой            47
# 429
#
#            date
# 0    2024-04-24
# 1    2024-04-24
# 2    2024-04-24
# 3    2024-04-24
# 4    2024-04-24
# ..          ...
# 425  2024-04-24
# 426  2024-04-24
# 427  2024-04-24
# 428  2024-04-24
# 429  2024-04-24
#
# [430 rows x 27 columns]

# %%
old_df.shape
# Out:
# (2279, 27)

# %%
# %%chime
# old_df = pd.read_csv('suburban.csv')
#
# new_df = df[[x not in old_df['url'].to_list() for x in df['url'].to_list()]]
# new_size = new_df.shape[0]
# display(new_df)
# Out:
#                               author        author_type  \
# 0                    Монолит Столица  real_estate_agent
# 1                        ID 87392027            unknown
# 2                           ID 53733            realtor
# 3                     ЭТАЖИ Подольск  real_estate_agent
# 4                     ЭТАЖИ Подольск  real_estate_agent
# ..                               ...                ...
# 425                      Home Market  real_estate_agent
# 426                 Светлана Заремба            realtor
# 427               Гульнара Абдуллина            realtor
# 428  АН Мегаполис-Сервис Юбилейная 8  real_estate_agent
# 429                  Михаил Максимов            realtor
#
#                                                    url  location deal_type  \
# 0     https://podolsk.cian.ru/sale/suburban/299274329/  Подольск      sale
# 1     https://podolsk.cian.ru/sale/suburban/300560807/  Подольск      sale
# 2     https://podolsk.cian.ru/sale/suburban/300899069/  Подольск      sale
# 3     https://podolsk.cian.ru/sale/suburban/299302858/  Подольск      sale
# 4     https://podolsk.cian.ru/sale/suburban/298492436/  Подольск      sale
# ..                                                 ...       ...       ...
# 425  https://balashikha.cian.ru/sale/suburban/29298...  Балашиха      sale
# 426  https://balashikha.cian.ru/sale/suburban/27844...  Балашиха      sale
# 427  https://balashikha.cian.ru/sale/suburban/28407...  Балашиха      sale
# 428  https://balashikha.cian.ru/sale/suburban/30068...  Балашиха      sale
# 429  https://balashikha.cian.ru/sale/suburban/29137...  Балашиха      sale
#
#     accommodation_type suburban_type  price_per_month  commissions     price  \
# 0             suburban         house               -1            0  12500000
# 1             suburban         house               -1            0  25000000
# 2             suburban         house               -1            0   1900000
# 3             suburban         house               -1            0  11000000
# 4             suburban         house               -1            0   8500000
# ..                 ...           ...              ...          ...       ...
# 425           suburban     townhouse               -1            0  26500000
# 426           suburban     townhouse               -1            0  27499000
# 427           suburban     townhouse               -1            0  17350000
# 428           suburban     townhouse               -1            0  14990000
# 429           suburban     townhouse               -1            0  12800000
#
#      ... sewage_system bathroom living_meters floors_count         phone  \
# 0    ...            -1       -1       85,1 м²            2  +79651405728
# 1    ...            -1       -1        185 м²            2  +79851813193
# 2    ...            -1       -1         52 м²            2  +79683348903
# 3    ...            -1       -1         62 м²            2  +79684552495
# 4    ...            -1       -1        200 м²            3  +79645599647
# ..   ...           ...      ...           ...          ...           ...
# 425  ...            -1       -1      229,6 м²            3  +79660505643
# 426  ...            -1       -1        260 м²            3  +79623689260
# 427  ...            -1       -1            -1            2  +79167257220
# 428  ...            -1       -1       85,5 м²            2  +79684988072
# 429  ...            -1       -1        166 м²            3  +79175096261
#
#      district      underground                   street  house_number  \
# 0                  м. Подольск        переулок Крымский          2/27
# 1                  м. Подольск  улица Малая Северовская            20
# 2                  м. Подольск       улица Коммунальная
# 3                м. Силикатная         Силикатная улица
# 4                  м. Подольск  улица Малая Зеленовская
# ..        ...              ...                      ...           ...
# 425                                    шоссе Леоновское           6к7
# 426                                      улица Студеная
# 427            м. Салтыковская          Граничная улица            14
# 428            м. Салтыковская           улица Рудневой            47
# 429
#
#            date
# 0    2024-04-24
# 1    2024-04-24
# 2    2024-04-24
# 3    2024-04-24
# 4    2024-04-24
# ..          ...
# 425  2024-04-24
# 426  2024-04-24
# 427  2024-04-24
# 428  2024-04-24
# 429  2024-04-24
#
# [428 rows x 27 columns]

# %%
if new_df.shape[0] > 0:
    full_df = (pd.concat([old_df,new_df])
            .drop_duplicates(subset=['url','author'],ignore_index=True)
            .reset_index(drop=True))

    full_df.to_csv('suburban.csv',index=False)

    
    print(f'Количество новых обьялений: {new_size}')

else:
    print('Новых обьявлений не обнаруженно')

print(f'Суммарное количество объялений: {full_df.shape[0]}')
# Out:
# Количество новых обьялений: 428
# Суммарное количество объялений: 2812

# %%
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="my_app")  # user_agent нужен для идентификации приложения

# Получение координат центра Москвы
moscow_location = geolocator.geocode("Москва, Россия")
moscow_coords = (moscow_location.latitude, moscow_location.longitude)

# Получение координат центра Раменского
ramenskoye_location = geolocator.geocode("Раменское, Московская область, Россия")
ramenskoye_coords = (ramenskoye_location.latitude, ramenskoye_location.longitude)

# Получение координат центра Жуковского
zhukovsky_location = geolocator.geocode("Жуковский, Московская область, Россия")
zhukovsky_coords = (zhukovsky_location.latitude, zhukovsky_location.longitude)

# Пример геокодирования объекта недвижимости
address = "улица Ленина, 10, Раменское район, Московская область, Россия"
location = geolocator.geocode(address)
property_coords = (location.latitude, location.longitude)

# %%
location
# Out:
# Location(улица Ленина, Красный Октябрь, Раменское, Раменский городской округ, Московская область, Центральный федеральный округ, 140104, Россия, (55.5799671, 38.1908862, 0.0))

# %%
zhukovsky_coords
# Out:
# (55.5972801, 38.1199863)

# %%
property_coords
# Out:
# (55.5799671, 38.1908862)
